# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error

# %%
df = pd.read_csv('IphoneData.csv')

# %%
#takes name of column
def plotLinearRegression(XName, yName):
    X = df[XName]
    y = df[yName]
    X = X.values.reshape(-1, 1)
    y = y.values.reshape(-1, 1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = .75)
    
    LR = LinearRegression().fit(X_train, y_train)
    y_pred = LR.predict(X_test)
    

    y_pred = LR.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    
    plt.plot(X_test, y_pred,color='blue')
    plt.scatter(X_train, y_train, color='red')
    plt.scatter(X_test, y_test, color='green')
    plt.xlabel(XName)
    plt.ylabel(yName)
    plt.text(min(X), max(y), 'R^2 = ' + str(r2))
    plt.show()
    
    r2 = r2_score(y_test, y_pred)    
    sse = np.sum((y_test - y_pred) ** 2)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    
   #print results
    print("R2 = " + str(r2))
    print("SSE = " + str(sse))
    print("MAPE = " + str(mape))

# %%
def plotDecisionTree(XName, yName):
    """
    X = df[XName]
    y = df[yName]
    X = X.values.reshape(-1, 1)
    y = y.values.reshape(-1, 1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20, train_size = .75)
    
    DT = tree.DecisionTreeRegressor().fit(X_train, y_train)
    y_pred = DT.predict(X_test)
    

    y_pred = DT.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    
    plt.scatter(X_train, y_train, color='red')
    plt.scatter(X_test, y_test, color='green')
    plt.xlabel(XName)
    plt.ylabel(yName)
    plt.text(min(X), max(y), 'R^2 = ' + str(r2))
    
    plt.figure(figsize=(15, 10))
    tree.plot_tree(DT, filled=True, rounded=True)
    
    plt.show()
    """

# %%
plotLinearRegression('DISPLAY (inch)', 'CO2E')
plotDecisionTree('DISPLAY (inch)', 'CO2E')
# Out:
# R2 = 0.24196056809396949
# SSE = 2106.5284113142
# MAPE = 0.1324733389844334

# %%
plotLinearRegression('STORAGE (gb)', 'CO2E')
# Out:
# R2 = 0.632158696648046
# SSE = 1022.2003285731342
# MAPE = 0.10004748460323619

# %%
plotLinearRegression('MEMORY (gb)', 'CO2E')
# Out:
# R2 = -0.03195366849171832
# SSE = 2867.7132485994443
# MAPE = 0.1396798474729949

# %%
plotLinearRegression('CPU (cores)', 'CO2E')
# Out:
# R2 = -0.09404144300836648
# SSE = 3040.25
# MAPE = 0.13679609557143035

# %%
plotLinearRegression('GPU (cores)', 'CO2E')
# Out:
# R2 = -0.04604192585351008
# SSE = 2906.863341786417
# MAPE = 0.14069804560994273

# %%
plotLinearRegression('NEURAL ENGINE (cores)', 'CO2E')
# Out:
# R2 = -0.09474412056809522
# SSE = 3042.202682382023
# MAPE = 0.1364191470152513

# %%
plotLinearRegression('WEIGHT (gm)', 'CO2E')
# Out:
# R2 = 0.32512750755890374
# SSE = 1875.4144171194366
# MAPE = 0.13618022189869045

# %%
plotLinearRegression('BATTERY (mAh)', 'CO2E')
# Out:
# R2 = 0.1982822540553466
# SSE = 2227.90680616803
# MAPE = 0.14107303461826606

# %%
plotLinearRegression('MAIN CAMERA (mp)', 'CO2E')
# Out:
# R2 = -0.11225147689447335
# SSE = 3090.854166666667
# MAPE = 0.13663215266365905

# %%
plotLinearRegression('FRONT CAMERA (mp)', 'CO2E')
# Out:
# R2 = 0.2127027918553397
# SSE = 2187.8333333333326
# MAPE = 0.10906142007975074

# %%
plotLinearRegression('Sum of megapixels', 'CO2E')
# Out:
# R2 = -0.12437973216163556
# SSE = 3124.557577366172
# MAPE = 0.13690436596821223
